# %% [markdown]
# <a href="https://colab.research.google.com/github/Ash-106/summer-of-code-2024/blob/main/projectML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                             title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rabieelkharoua/students-performance-dataset                     📚 Students Performance Dataset 📚                    66KB  2024-06-12 23:09:20           5519        112  1.0
# nelgiriyewithana/most-streamed-spotify-songs-2024               Most Streamed Spotify Songs 2024                   496KB  2024-06-15 18:50:51           4392         96  1.0
# viveksharmar/flight-price-data                                  Flight Price Prediction                            115KB  2024-06-01 17:17:11           1292         23  1.0
# shreyanshverma27/online-sales-dataset-popular-marketplace-data  Online Sales Dataset - Popular Marketplace Data      7KB  2024-05-25 23:55:26          12469        220  1.0
# rabieelkharoua/predict-online-dating-matches-dataset            💌 Predict Online Dating Matches Dataset              7KB  2024-06-21 07:40:23            664         25  1.0
# mayankanand2701/top-1000-youtube-channels-in-the-world          Top 1000 YouTube Channels in the World 🌐📊🎥          25KB  2024-06-25 03:30:00            666         23  1.0
# kanchana1990/e-commerce-womens-clothing-data-2024               E-Commerce Women's Clothing Data 2024              482KB  2024-06-20 19:26:33            559         26  1.0
# bhavikjikadara/retail-transactional-dataset                     Retail Transactional Dataset                        25MB  2024-06-18 08:39:00            976         25  1.0
# nikhil7280/weather-type-classification                          Weather Type Classification                        186KB  2024-06-23 18:15:05           1079         33  1.0
# ritiksharma07/imdb-top-1000-movies-dataset                      IMDB Top 1000 Movies Dataset                        87KB  2024-06-18 09:51:21            592         25  1.0
# teocalvo/teomewhy-loyalty-system                                TeoMeWhy Loyalty System                             24MB  2024-06-28 13:34:50            384        422  1.0
# rabieelkharoua/predicting-hiring-decisions-in-recruitment-data  💼 Predicting Hiring Decisions in Recruitment Data   28KB  2024-06-17 21:13:48            893         26  1.0
# rabieelkharoua/predict-online-gaming-behavior-dataset           🎮 Predict Online Gaming Behavior Dataset           904KB  2024-06-21 02:58:42            565         26  1.0
# zeesolver/data-eng-salary-2024                                  Data Developer Salary in 2024💰                     108KB  2024-06-10 07:33:22           3042         48  1.0
# mayankanand2701/samsung-stock-price-dataset                     Samsung Stock Price Dataset 📱🏭📈                    114KB  2024-06-13 14:51:11           1524         34  1.0
# kanchana1990/worlds-tallest-men-and-women                       World's Tallest Men and Women Dataset               11KB  2024-06-21 10:31:30            589         29  1.0
# damirdizdarevic/uefa-euro-2024-players                          UEFA EURO 2024 - Players                            15KB  2024-06-08 18:07:29           3041         63  1.0
# rabieelkharoua/alzheimers-disease-dataset                       🧠 Alzheimer's Disease Dataset 🧠                    268KB  2024-06-11 20:24:30           1573         45  1.0
# rabieelkharoua/predicting-manufacturing-defects-dataset         🏭 Predicting Manufacturing Defects Dataset         363KB  2024-06-17 21:47:37            904         25  1.0
# informrohit1/smartphones-dataset                                Smartphones_Dataset                                 23KB  2024-06-09 10:24:51           3327         62  1.0

# %%
! kaggle datasets download -d rupakroy/online-payments-fraud-detection-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rupakroy/online-payments-fraud-detection-dataset
# License(s): CC-BY-NC-SA-4.0
# Downloading online-payments-fraud-detection-dataset.zip to /content
#  92% 163M/178M [00:00<00:00, 184MB/s]
# 100% 178M/178M [00:00<00:00, 202MB/s]

# %%
! unzip  online-payments-fraud-detection-dataset.zip
# Out:
# Archive:  online-payments-fraud-detection-dataset.zip
#   inflating: PS_20174392719_1491204439457_log.csv

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv('PS_20174392719_1491204439457_log.csv')
df['step'].fillna(df['step'].mean(), inplace=True)
df['amount'].fillna(df['amount'].mean(), inplace=True)
df['oldbalanceOrg'].fillna(df['oldbalanceOrg'].mean(), inplace=True)
df['newbalanceOrig'].fillna(df['newbalanceOrig'].mean(), inplace=True)

# %%
print(df.head())
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
print(df.describe())
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00    0.000000e+00
# 75%      9.430367e+05    1.111909e+06  0.000000e+00    0.000000e+00
# max      3.560159e+08    3.561793e+08  1.000000e+00    1.000000e+00

# %%
for col in df.columns:
    print(col)
# Out:
# step
# amount
# oldbalanceOrg
# newbalanceOrig
# oldbalanceDest
# newbalanceDest
# isFraud
# isFlaggedFraud
# CASH_IN
# CASH_OUT
# DEBIT
# PAYMENT
# TRANSFER

# %%
df
# Out:
#              step    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2        0.000000  0.000002       0.000003        0.000000        0.000000
# 3        0.000000  0.000002       0.000003        0.000000        0.000059
# 251      0.000000  0.000030       0.000047        0.000000        0.000000
# 252      0.000000  0.000030       0.000047        0.000000        0.000074
# 680      0.000000  0.000218       0.000338        0.000000        0.000000
# ...           ...       ...            ...             ...             ...
# 1551496  0.206199  0.000175       0.000000        0.000000        0.000000
# 2930549  0.307278  0.001245       0.070413        0.086936        0.000973
# 1681909  0.212938  0.000111       0.000102        0.000000        0.000000
# 5078482  0.477089  0.001744       0.026844        0.035508        0.001783
# 2261074  0.250674  0.004494       0.000849        0.000000        0.000078
#
#          newbalanceDest  isFraud  isFlaggedFraud  CASH_IN  CASH_OUT  DEBIT  \
# 2              0.000000        1               0    False     False  False
# 3              0.000000        1               0    False      True  False
# 251            0.000000        1               0    False     False  False
# 252            0.000000        1               0    False      True  False
# 680            0.000000        1               0    False     False  False
# ...                 ...      ...             ...      ...       ...    ...
# 1551496        0.000000        0               0    False     False  False
# 2930549        0.000650        0               0     True     False  False
# 1681909        0.000000        0               0    False     False  False
# 5078482        0.001747        0               0     True     False  False
# 2261074        0.001244        0               0    False      True  False
#
#          PAYMENT  TRANSFER
# 2          False      True
# 3          False     False
# 251        False      True
# 252        False     False
# 680        False      True
# ...          ...       ...
# 1551496     True     False
# 2930549    False     False
# 1681909     True     False
# 5078482    False     False
# 2261074    False     False
#
# [16426 rows x 13 columns]

# %%
one_hot=pd.get_dummies(df['type'])
df=df.drop('type',axis=1)
df=df.join(one_hot)

# %%
df
# Out:
#              step    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2        0.000000  0.000002       0.000003        0.000000        0.000000
# 3        0.000000  0.000002       0.000003        0.000000        0.000059
# 251      0.000000  0.000030       0.000047        0.000000        0.000000
# 252      0.000000  0.000030       0.000047        0.000000        0.000074
# 680      0.000000  0.000218       0.000338        0.000000        0.000000
# ...           ...       ...            ...             ...             ...
# 1551496  0.206199  0.000175       0.000000        0.000000        0.000000
# 2930549  0.307278  0.001245       0.070413        0.086936        0.000973
# 1681909  0.212938  0.000111       0.000102        0.000000        0.000000
# 5078482  0.477089  0.001744       0.026844        0.035508        0.001783
# 2261074  0.250674  0.004494       0.000849        0.000000        0.000078
#
#          newbalanceDest  isFraud  isFlaggedFraud  CASH_IN  CASH_OUT  DEBIT  \
# 2              0.000000        1               0    False     False  False
# 3              0.000000        1               0    False      True  False
# 251            0.000000        1               0    False     False  False
# 252            0.000000        1               0    False      True  False
# 680            0.000000        1               0    False     False  False
# ...                 ...      ...             ...      ...       ...    ...
# 1551496        0.000000        0               0    False     False  False
# 2930549        0.000650        0               0     True     False  False
# 1681909        0.000000        0               0    False     False  False
# 5078482        0.001747        0               0     True     False  False
# 2261074        0.001244        0               0    False      True  False
#
#          PAYMENT  TRANSFER
# 2          False      True
# 3          False     False
# 251        False      True
# 252        False     False
# 680        False      True
# ...          ...       ...
# 1551496     True     False
# 2930549    False     False
# 1681909     True     False
# 5078482    False     False
# 2261074    False     False
#
# [16426 rows x 13 columns]

# %%
df["nameorig_type"]=df['nameOrig'].str[:1]

# %%
df
# Out:
#              step    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2        0.000000  0.000002       0.000003        0.000000        0.000000
# 3        0.000000  0.000002       0.000003        0.000000        0.000059
# 251      0.000000  0.000030       0.000047        0.000000        0.000000
# 252      0.000000  0.000030       0.000047        0.000000        0.000074
# 680      0.000000  0.000218       0.000338        0.000000        0.000000
# ...           ...       ...            ...             ...             ...
# 1551496  0.206199  0.000175       0.000000        0.000000        0.000000
# 2930549  0.307278  0.001245       0.070413        0.086936        0.000973
# 1681909  0.212938  0.000111       0.000102        0.000000        0.000000
# 5078482  0.477089  0.001744       0.026844        0.035508        0.001783
# 2261074  0.250674  0.004494       0.000849        0.000000        0.000078
#
#          newbalanceDest  isFraud  isFlaggedFraud  CASH_IN  CASH_OUT  DEBIT  \
# 2              0.000000        1               0    False     False  False
# 3              0.000000        1               0    False      True  False
# 251            0.000000        1               0    False     False  False
# 252            0.000000        1               0    False      True  False
# 680            0.000000        1               0    False     False  False
# ...                 ...      ...             ...      ...       ...    ...
# 1551496        0.000000        0               0    False     False  False
# 2930549        0.000650        0               0     True     False  False
# 1681909        0.000000        0               0    False     False  False
# 5078482        0.001747        0               0     True     False  False
# 2261074        0.001244        0               0    False      True  False
#
#          PAYMENT  TRANSFER
# 2          False      True
# 3          False     False
# 251        False      True
# 252        False     False
# 680        False      True
# ...          ...       ...
# 1551496     True     False
# 2930549    False     False
# 1681909     True     False
# 5078482    False     False
# 2261074    False     False
#
# [16426 rows x 13 columns]

# %%
df["namedest_type"]=df['nameDest'].str[:1]

# %%
df
# Out:
#          step      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     9839.64  C1231006815      170136.00       160296.36
# 1           1     1864.28  C1666544295       21249.00        19384.72
# 2           1      181.00  C1305486145         181.00            0.00
# 3           1      181.00   C840083671         181.00            0.00
# 4           1    11668.14  C2048537720       41554.00        29885.86
# ...       ...         ...          ...            ...             ...
# 6362615   743   339682.13   C786484425      339682.13            0.00
# 6362616   743  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743   850002.52  C1685995037      850002.52            0.00
# 6362619   743   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0        M1979787155            0.00            0.00        0               0
# 1        M2044282225            0.00            0.00        0               0
# 2         C553264065            0.00            0.00        1               0
# 3          C38997010        21182.00            0.00        1               0
# 4        M1230701703            0.00            0.00        0               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290            0.00       339682.13        1               0
# 6362616  C1881841831            0.00            0.00        1               0
# 6362617  C1365125890        68488.84      6379898.11        1               0
# 6362618  C2080388513            0.00            0.00        1               0
# 6362619   C873221189      6510099.11      7360101.63        1               0
#
#          CASH_IN  CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type  \
# 0          False     False  False     True     False             C
# 1          False     False  False     True     False             C
# 2          False     False  False    False      True             C
# 3          False      True  False    False     False             C
# 4          False     False  False     True     False             C
# ...          ...       ...    ...      ...       ...           ...
# 6362615    False      True  False    False     False             C
# 6362616    False     False  False    False      True             C
# 6362617    False      True  False    False     False             C
# 6362618    False     False  False    False      True             C
# 6362619    False      True  False    False     False             C
#
#         namedest_type
# 0                   M
# 1                   M
# 2                   C
# 3                   C
# 4                   M
# ...               ...
# 6362615             C
# 6362616             C
# 6362617             C
# 6362618             C
# 6362619             C
#
# [6362620 rows x 17 columns]

# %%
df['namedest_type'].unique()
# Out:
# array(['M', 'C'], dtype=object)

# %%
df.drop(columns=['nameDest'])
# Out:
#          step      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     9839.64  C1231006815      170136.00       160296.36
# 1           1     1864.28  C1666544295       21249.00        19384.72
# 2           1      181.00  C1305486145         181.00            0.00
# 3           1      181.00   C840083671         181.00            0.00
# 4           1    11668.14  C2048537720       41554.00        29885.86
# ...       ...         ...          ...            ...             ...
# 6362615   743   339682.13   C786484425      339682.13            0.00
# 6362616   743  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743   850002.52  C1685995037      850002.52            0.00
# 6362619   743   850002.52  C1280323807      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  CASH_IN  \
# 0                  0.00            0.00        0               0    False
# 1                  0.00            0.00        0               0    False
# 2                  0.00            0.00        1               0    False
# 3              21182.00            0.00        1               0    False
# 4                  0.00            0.00        0               0    False
# ...                 ...             ...      ...             ...      ...
# 6362615            0.00       339682.13        1               0    False
# 6362616            0.00            0.00        1               0    False
# 6362617        68488.84      6379898.11        1               0    False
# 6362618            0.00            0.00        1               0    False
# 6362619      6510099.11      7360101.63        1               0    False
#
#          CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type namedest_type
# 0           False  False     True     False             C             M
# 1           False  False     True     False             C             M
# 2           False  False    False      True             C             C
# 3            True  False    False     False             C             C
# 4           False  False     True     False             C             M
# ...           ...    ...      ...       ...           ...           ...
# 6362615      True  False    False     False             C             C
# 6362616     False  False    False      True             C             C
# 6362617      True  False    False     False             C             C
# 6362618     False  False    False      True             C             C
# 6362619      True  False    False     False             C             C
#
# [6362620 rows x 16 columns]

# %%
df=df.drop(columns=["nameorig_type","nameOrig","nameDest"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-b7c152c41f6b> in <cell line: 1>()
# ----> 1 df=df.drop(columns=["nameorig_type","nameOrig","nameDest"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['nameorig_type', 'nameOrig', 'nameDest'] not found in axis"

# %%
df
# Out:
#          step      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     9839.64  C1231006815      170136.00       160296.36
# 1           1     1864.28  C1666544295       21249.00        19384.72
# 2           1      181.00  C1305486145         181.00            0.00
# 3           1      181.00   C840083671         181.00            0.00
# 4           1    11668.14  C2048537720       41554.00        29885.86
# ...       ...         ...          ...            ...             ...
# 6362615   743   339682.13   C786484425      339682.13            0.00
# 6362616   743  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743   850002.52  C1685995037      850002.52            0.00
# 6362619   743   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0        M1979787155            0.00            0.00        0               0
# 1        M2044282225            0.00            0.00        0               0
# 2         C553264065            0.00            0.00        1               0
# 3          C38997010        21182.00            0.00        1               0
# 4        M1230701703            0.00            0.00        0               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290            0.00       339682.13        1               0
# 6362616  C1881841831            0.00            0.00        1               0
# 6362617  C1365125890        68488.84      6379898.11        1               0
# 6362618  C2080388513            0.00            0.00        1               0
# 6362619   C873221189      6510099.11      7360101.63        1               0
#
#          CASH_IN  CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type  \
# 0          False     False  False     True     False             C
# 1          False     False  False     True     False             C
# 2          False     False  False    False      True             C
# 3          False      True  False    False     False             C
# 4          False     False  False     True     False             C
# ...          ...       ...    ...      ...       ...           ...
# 6362615    False      True  False    False     False             C
# 6362616    False     False  False    False      True             C
# 6362617    False      True  False    False     False             C
# 6362618    False     False  False    False      True             C
# 6362619    False      True  False    False     False             C
#
#         namedest_type
# 0                   M
# 1                   M
# 2                   C
# 3                   C
# 4                   M
# ...               ...
# 6362615             C
# 6362616             C
# 6362617             C
# 6362618             C
# 6362619             C
#
# [6362620 rows x 17 columns]

# %%
one_hot=pd.get_dummies(df['namedest_type'])
df=df.drop('namedest_type',axis=1)
df=df.join(one_hot)

# %%
df
# Out:
#          step      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     9839.64  C1231006815      170136.00       160296.36
# 1           1     1864.28  C1666544295       21249.00        19384.72
# 2           1      181.00  C1305486145         181.00            0.00
# 3           1      181.00   C840083671         181.00            0.00
# 4           1    11668.14  C2048537720       41554.00        29885.86
# ...       ...         ...          ...            ...             ...
# 6362615   743   339682.13   C786484425      339682.13            0.00
# 6362616   743  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743   850002.52  C1685995037      850002.52            0.00
# 6362619   743   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0        M1979787155            0.00            0.00        0               0
# 1        M2044282225            0.00            0.00        0               0
# 2         C553264065            0.00            0.00        1               0
# 3          C38997010        21182.00            0.00        1               0
# 4        M1230701703            0.00            0.00        0               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290            0.00       339682.13        1               0
# 6362616  C1881841831            0.00            0.00        1               0
# 6362617  C1365125890        68488.84      6379898.11        1               0
# 6362618  C2080388513            0.00            0.00        1               0
# 6362619   C873221189      6510099.11      7360101.63        1               0
#
#          CASH_IN  CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type      C  \
# 0          False     False  False     True     False             C  False
# 1          False     False  False     True     False             C  False
# 2          False     False  False    False      True             C   True
# 3          False      True  False    False     False             C   True
# 4          False     False  False     True     False             C  False
# ...          ...       ...    ...      ...       ...           ...    ...
# 6362615    False      True  False    False     False             C   True
# 6362616    False     False  False    False      True             C   True
# 6362617    False      True  False    False     False             C   True
# 6362618    False     False  False    False      True             C   True
# 6362619    False      True  False    False     False             C   True
#
#              M
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
# ...        ...
# 6362615  False
# 6362616  False
# 6362617  False
# 6362618  False
# 6362619  False
#
# [6362620 rows x 18 columns]

# %%
df=df.drop(columns=["nameorig_type","nameOrig","nameDest"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-b7c152c41f6b> in <cell line: 1>()
# ----> 1 df=df.drop(columns=["nameorig_type","nameOrig","nameDest"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['nameorig_type', 'nameOrig', 'nameDest'] not found in axis"

# %%
df
# Out:
#          step      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1     9839.64  C1231006815      170136.00       160296.36
# 1           1     1864.28  C1666544295       21249.00        19384.72
# 2           1      181.00  C1305486145         181.00            0.00
# 3           1      181.00   C840083671         181.00            0.00
# 4           1    11668.14  C2048537720       41554.00        29885.86
# ...       ...         ...          ...            ...             ...
# 6362615   743   339682.13   C786484425      339682.13            0.00
# 6362616   743  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743   850002.52  C1685995037      850002.52            0.00
# 6362619   743   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0        M1979787155            0.00            0.00        0               0
# 1        M2044282225            0.00            0.00        0               0
# 2         C553264065            0.00            0.00        1               0
# 3          C38997010        21182.00            0.00        1               0
# 4        M1230701703            0.00            0.00        0               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290            0.00       339682.13        1               0
# 6362616  C1881841831            0.00            0.00        1               0
# 6362617  C1365125890        68488.84      6379898.11        1               0
# 6362618  C2080388513            0.00            0.00        1               0
# 6362619   C873221189      6510099.11      7360101.63        1               0
#
#          CASH_IN  CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type  \
# 0          False     False  False     True     False             C
# 1          False     False  False     True     False             C
# 2          False     False  False    False      True             C
# 3          False      True  False    False     False             C
# 4          False     False  False     True     False             C
# ...          ...       ...    ...      ...       ...           ...
# 6362615    False      True  False    False     False             C
# 6362616    False     False  False    False      True             C
# 6362617    False      True  False    False     False             C
# 6362618    False     False  False    False      True             C
# 6362619    False      True  False    False     False             C
#
#         namedest_type
# 0                   M
# 1                   M
# 2                   C
# 3                   C
# 4                   M
# ...               ...
# 6362615             C
# 6362616             C
# 6362617             C
# 6362618             C
# 6362619             C
#
# [6362620 rows x 17 columns]

# %%
def norm_column(df,col):
    df_col=df[col]
    max_val=df_col.max()
    min_val=df_col.min()
    df[col]=(df_col-min_val)/(max_val-min_val)

# %%
norm_cols=[
    "step",
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest"
]

for col in norm_cols:
    norm_column(df,col)

# %%
df
# Out:
#          step    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         0.0  0.000106  C1231006815       0.002855        0.003233
# 1         0.0  0.000020  C1666544295       0.000357        0.000391
# 2         0.0  0.000002  C1305486145       0.000003        0.000000
# 3         0.0  0.000002   C840083671       0.000003        0.000000
# 4         0.0  0.000126  C2048537720       0.000697        0.000603
# ...       ...       ...          ...            ...             ...
# 6362615   1.0  0.003674   C786484425       0.005701        0.000000
# 6362616   1.0  0.068272  C1529008245       0.105923        0.000000
# 6362617   1.0  0.068272  C1162922333       0.105923        0.000000
# 6362618   1.0  0.009195  C1685995037       0.014265        0.000000
# 6362619   1.0  0.009195  C1280323807       0.014265        0.000000
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0        M1979787155        0.000000        0.000000        0               0
# 1        M2044282225        0.000000        0.000000        0               0
# 2         C553264065        0.000000        0.000000        1               0
# 3          C38997010        0.000059        0.000000        1               0
# 4        M1230701703        0.000000        0.000000        0               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290        0.000000        0.000954        1               0
# 6362616  C1881841831        0.000000        0.000000        1               0
# 6362617  C1365125890        0.000192        0.017912        1               0
# 6362618  C2080388513        0.000000        0.000000        1               0
# 6362619   C873221189        0.018286        0.020664        1               0
#
#          CASH_IN  CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type  \
# 0          False     False  False     True     False             C
# 1          False     False  False     True     False             C
# 2          False     False  False    False      True             C
# 3          False      True  False    False     False             C
# 4          False     False  False     True     False             C
# ...          ...       ...    ...      ...       ...           ...
# 6362615    False      True  False    False     False             C
# 6362616    False     False  False    False      True             C
# 6362617    False      True  False    False     False             C
# 6362618    False     False  False    False      True             C
# 6362619    False      True  False    False     False             C
#
#         namedest_type
# 0                   M
# 1                   M
# 2                   C
# 3                   C
# 4                   M
# ...               ...
# 6362615             C
# 6362616             C
# 6362617             C
# 6362618             C
# 6362619             C
#
# [6362620 rows x 17 columns]

# %%
df_isfraud=df[df['isFraud']==1]
df_notfraud=df[df['isFraud']==0]

# %%
df_isfraud
# Out:
#          step    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2         0.0  0.000002  C1305486145       0.000003             0.0
# 3         0.0  0.000002   C840083671       0.000003             0.0
# 251       0.0  0.000030  C1420196421       0.000047             0.0
# 252       0.0  0.000030  C2101527076       0.000047             0.0
# 680       0.0  0.000218   C137533655       0.000338             0.0
# ...       ...       ...          ...            ...             ...
# 6362615   1.0  0.003674   C786484425       0.005701             0.0
# 6362616   1.0  0.068272  C1529008245       0.105923             0.0
# 6362617   1.0  0.068272  C1162922333       0.105923             0.0
# 6362618   1.0  0.009195  C1685995037       0.014265             0.0
# 6362619   1.0  0.009195  C1280323807       0.014265             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2         C553264065        0.000000        0.000000        1               0
# 3          C38997010        0.000059        0.000000        1               0
# 251       C972765878        0.000000        0.000000        1               0
# 252      C1007251739        0.000074        0.000000        1               0
# 680      C1848415041        0.000000        0.000000        1               0
# ...              ...             ...             ...      ...             ...
# 6362615   C776919290        0.000000        0.000954        1               0
# 6362616  C1881841831        0.000000        0.000000        1               0
# 6362617  C1365125890        0.000192        0.017912        1               0
# 6362618  C2080388513        0.000000        0.000000        1               0
# 6362619   C873221189        0.018286        0.020664        1               0
#
#          CASH_IN  CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type  \
# 2          False     False  False    False      True             C
# 3          False      True  False    False     False             C
# 251        False     False  False    False      True             C
# 252        False      True  False    False     False             C
# 680        False     False  False    False      True             C
# ...          ...       ...    ...      ...       ...           ...
# 6362615    False      True  False    False     False             C
# 6362616    False     False  False    False      True             C
# 6362617    False      True  False    False     False             C
# 6362618    False     False  False    False      True             C
# 6362619    False      True  False    False     False             C
#
#         namedest_type
# 2                   C
# 3                   C
# 251                 C
# 252                 C
# 680                 C
# ...               ...
# 6362615             C
# 6362616             C
# 6362617             C
# 6362618             C
# 6362619             C
#
# [8213 rows x 17 columns]

# %%
df_notfraud
# Out:
#              step    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0        0.000000  0.000106  C1231006815       0.002855        0.003233
# 1        0.000000  0.000020  C1666544295       0.000357        0.000391
# 4        0.000000  0.000126  C2048537720       0.000697        0.000603
# 5        0.000000  0.000085    C90045638       0.000904        0.000929
# 6        0.000000  0.000077   C154988899       0.003075        0.003551
# ...           ...       ...          ...            ...             ...
# 6362319  0.966307  0.000093   C642813806       0.008707        0.010289
# 6362320  0.966307  0.001722   C691808084       0.000065        0.000000
# 6362321  0.966307  0.002015   C102120699       0.002820        0.000000
# 6362322  0.966307  0.000888   C614459560       0.000226        0.000000
# 6362323  0.966307  0.000020    C49652609       0.000343        0.000374
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0        M1979787155         0.00000        0.000000        0               0
# 1        M2044282225         0.00000        0.000000        0               0
# 4        M1230701703         0.00000        0.000000        0               0
# 5         M573487274         0.00000        0.000000        0               0
# 6         M408069119         0.00000        0.000000        0               0
# ...              ...             ...             ...      ...             ...
# 6362319   M747723689         0.00000        0.000000        0               0
# 6362320  C1818183087         0.00000        0.000447        0               0
# 6362321  C1515639522         0.00007        0.000593        0               0
# 6362322   C855350324         0.00000        0.000230        0               0
# 6362323  C1799009964         0.00053        0.000535        0               0
#
#          CASH_IN  CASH_OUT  DEBIT  PAYMENT  TRANSFER nameorig_type  \
# 0          False     False  False     True     False             C
# 1          False     False  False     True     False             C
# 4          False     False  False     True     False             C
# 5          False     False  False     True     False             C
# 6          False     False  False     True     False             C
# ...          ...       ...    ...      ...       ...           ...
# 6362319    False     False  False     True     False             C
# 6362320    False      True  False    False     False             C
# 6362321    False      True  False    False     False             C
# 6362322    False     False  False    False      True             C
# 6362323    False     False   True    False     False             C
#
#         namedest_type
# 0                   M
# 1                   M
# 4                   M
# 5                   M
# 6                   M
# ...               ...
# 6362319             M
# 6362320             C
# 6362321             C
# 6362322             C
# 6362323             C
#
# [6354407 rows x 17 columns]

# %%
df_notfraud=df_notfraud.sample(n=8213)

# %%
df=pd.concat([df_isfraud,df_notfraud])

# %%
# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %%
df
# Out:
#              step    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 2        0.000000  0.000002       0.000003        0.000000        0.000000
# 3        0.000000  0.000002       0.000003        0.000000        0.000059
# 251      0.000000  0.000030       0.000047        0.000000        0.000000
# 252      0.000000  0.000030       0.000047        0.000000        0.000074
# 680      0.000000  0.000218       0.000338        0.000000        0.000000
# ...           ...       ...            ...             ...             ...
# 1551496  0.206199  0.000175       0.000000        0.000000        0.000000
# 2930549  0.307278  0.001245       0.070413        0.086936        0.000973
# 1681909  0.212938  0.000111       0.000102        0.000000        0.000000
# 5078482  0.477089  0.001744       0.026844        0.035508        0.001783
# 2261074  0.250674  0.004494       0.000849        0.000000        0.000078
#
#          newbalanceDest  isFraud  isFlaggedFraud  CASH_IN  CASH_OUT  DEBIT  \
# 2              0.000000        1               0    False     False  False
# 3              0.000000        1               0    False      True  False
# 251            0.000000        1               0    False     False  False
# 252            0.000000        1               0    False      True  False
# 680            0.000000        1               0    False     False  False
# ...                 ...      ...             ...      ...       ...    ...
# 1551496        0.000000        0               0    False     False  False
# 2930549        0.000650        0               0     True     False  False
# 1681909        0.000000        0               0    False     False  False
# 5078482        0.001747        0               0     True     False  False
# 2261074        0.001244        0               0    False      True  False
#
#          PAYMENT  TRANSFER namedest_type
# 2          False      True             C
# 3          False     False             C
# 251        False      True             C
# 252        False     False             C
# 680        False      True             C
# ...          ...       ...           ...
# 1551496     True     False             M
# 2930549    False     False             C
# 1681909     True     False             M
# 5078482    False     False             C
# 2261074    False     False             C
#
# [16426 rows x 14 columns]

# %%
# Split the data into features (X) and target (y)

X = df.drop('isFraud', axis=1)
y = df['isFraud']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9872185027388922

# %%
# Export the first three decision trees from the forest

for i in range(3):
    tree = rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
param_dist = {'n_estimators': randint(50,500),
              'max_depth': randint(1,20)}

# Create a random forest classifier
rf = RandomForestClassifier()

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(rf,
                                 param_distributions = param_dist,
                                 n_iter=5,
                                 cv=5)

# Fit the random search object to the data
rand_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7e77cb6d7310>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7e77cb6d6d70>})

# %%
# Create a variable for the best model
best_rf = rand_search.best_estimator_

# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': 14, 'n_estimators': 147}

# %%
# Generate predictions with the best model
y_pred = best_rf.predict(X_test)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.987522824102252
# Precision: 0.9810874704491725
# Recall: 0.9946075494307969

# %%
# Create a series containing feature importances from the model and feature names from the training data
feature_importances = pd.Series(best_rf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# Plot a simple bar chart
feature_importances.plot.bar();

# %%
! pip install fastapi uvicorn
# Out:
# Collecting fastapi
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.3 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.3 MB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.7.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.2)
# Collecting fastapi-cli>=0.0.2 (from fastapi)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting httpx>=0.23.0 (from fastapi)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.5 MB/s eta 0:00:00
# Collecting orjson>=3.2.1 (from fastapi)
#   Downloading orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 15.1 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi)
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Collecting h11>=0.8 (from uvicorn)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.18.4)
# Collecting httptools>=0.5.0 (from uvicorn)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 12.7 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 21.9 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.8 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.23.0->fastapi) (1.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# Installing collected packages: websockets, uvloop, ujson, python-multipart, python-dotenv, orjson, httptools, h11, dnspython, watchfiles, uvicorn, starlette, httpcore, email_validator, httpx, fastapi-cli, fastapi
# Successfully installed dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 orjson-3.10.5 python-dotenv-1.0.1 python-multipart-0.0.9 starlette-0.37.2 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0

# %%
# Importing Necessary modules
from fastapi import FastAPI
import uvicorn

# Declaring our FastAPI instance
app = FastAPI()

# Defining path operation for root endpoint
@app.get('/')
def main():
	return {'message': 'Welcome to API!'}

# Defining path operation for /name endpoint
@app.post('/detect')
def hello_name(params : dict()):
	# Defining a function that takes only string as input and output the
	  input_df = pd.DataFrame([params])

    # Make prediction using the trained model
    prediction = best_rf.predict(input_df)[0]

    # Return the prediction
    return {'fraud_prediction': int(prediction)}  # Convert prediction to integer

# %%
uvicorn.run(app,host="0.0.0.0",port=8000)
